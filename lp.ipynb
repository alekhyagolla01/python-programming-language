# %%
t = []
for i in range(11,16):
  t.append(int(input()))


print(t)
# Out:
# 100
# 11
# 18
# 800
# 300
# [100, 11, 18, 800, 300]

# %%
a = 'alekhya'
b = {}
for i in a:
  if i in b:
    b[i] = b[i]+1
  else:
    b[i] = 1

print(b)
# Out:
# {'a': 2, 'l': 1, 'e': 1, 'k': 1, 'h': 1, 'y': 1}

# %%
a = 'alekhya'
b = ''
for i in a:
  if i not in b:
    b = b +i
print(b)
# Out:
# alekhy

# %%
s = input('enter the string')
count = 0
for i in s:
  if i.lower() in 'aeiou':
    count = count + 1
print(count)
# Out:
# enter the stringaluu
# 3

# %%
s = 'python'
rev = ''
for i in s:
  rev = i + s
print(rev)
# Out:
# npython

# %%
s = 'python'
for i in s:
  print(i,end='')
# Out:
# python

# %%
s = 'python'
count = 0
for i in s:
  count = count+1
  print(count)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
a = input('enter the string')
count = 0
for i in a:
  if i.lower() not in 'aeiou':
    count = count + 1
print(count)
# Out:
# enter the stringalekhya
# 4

# %%
s = 'alelkhya123'
count = 0
for i in s:
  if i.isdigit():
    count = count + 1
print(count)
# Out:
# 3

# %%
s = 'Allu'
count = 0
for i in s:
  if i.isupper():
    count = count + 1
print(count)
# Out:
# 1

# %%
s = 'alekhya'
a = ''
for i in s:
  if i not in a:
    a = a + i
print(a)
# Out:
# alekhy

# %%
a = 'alekhya'
for i in range(0,len(a),2):
    print(a[i])
# Out:
# a
# e
# h
# a

# %%
a = 'alekhya'
rev = ''
for i in a:
  rev = i + rev
print(rev)
# Out:
# ayhkela

# %%
s = 'alekhya'
a = 'a'
count = 0
for i in s:
  if i == a:
    count = count + 1
print(count)
# Out:
# 2

# %%
s = 'alekhya'
a = 'a'
count = 0
for i in range(len(s)):
  if s[i] == a:
    count = count +1
print(count)
# Out:
# 2

# %%
n = int(input('enter the input'))
largest = 0
while n > 0:
  res = n % 10
  if
