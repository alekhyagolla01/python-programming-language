# %%
a = {'name':'alekhya','age':22,'city':'hyd'}
print(a)
print(a['name'])
print(a.keys())
print(a.values())
print(a.get('city'))
# Out:
# {'name': 'alekhya', 'age': 22, 'city': 'hyd'}
# alekhya
# dict_keys(['name', 'age', 'city'])
# dict_values(['alekhya', 22, 'hyd'])
# hyd

# %%
a = {'name':'alekhya','age':22,'city':'hyd'}
b = {'study':'cse'}
a.update(b)
print(a)
# Out:
# {'name': 'alekhya', 'age': 22, 'city': 'hyd', 'study': 'cse'}

# %%
a = {'name':'alekhya','age':22,'city':'hyd'}
a.pop('age')
print(a)
# Out:
# {'name': 'alekhya', 'city': 'hyd'}

# %%
a = {'name':'alekhya','age':22,'city':'hyd'}
print('name' in a)
# Out:
# True

# %%
a = {'name':'allu','age':22,'city':'hyd'}
b= a
print(b)
a.update({'course':'ass'})
print(b)
# Out:
# {'name': 'allu', 'age': 22, 'city': 'hyd'}
# {'name': 'allu', 'age': 22, 'city': 'hyd', 'course': 'ass'}

# %%
a = {'name':'allu','age':22,'city':'hyd'}
a.items()
print(len(a))
# Out:
# 3

# %%
a.setdefault('hyyyy','ass')
print(a)
# Out:
# {'name': 'allu', 'age': 22, 'city': 'hyd', 'hyyyy': 'ass'}

# %%
a = {'name':'allu','age':22,'city':'hyd'}
a.clear()
print(a)
# Out:
# {}

# %%
a = {'a':3,'b':4,'c':6}
print(max(a))
# Out:
# c

# %%
a = {'a':3,'b':4,'c':6}
b = list(a.keys())
print(b[:2])
# Out:
# ['a', 'b']

# %%
a = [('a',1)]
b = [('b',2)]
d = dict(zip(a,b))
print(d)
# Out:
# {('a', 1): ('b', 2)}

# %%
a = ['a','b']
b = [1,2]
d = dict(zip(a,b))
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
a = {'a':3,'b':4,'c':6}
d = dict(sorted(a.items()))
print(d)
# Out:
# {'a': 3, 'b': 4, 'c': 6}
