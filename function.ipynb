# %%
def alekhya():
  print('python')
alekhya()
# Out:
# python

# %%
def display(x):
  print('hello')
  print(x)
display(10)
# Out:
# hello
# 10

# %%
def is_even(x):
  if x % 2 == 0:
    print('even')
  else:
    print('odd')
is_even(12)
# Out:
# even

# %%
def alekhya():
  print('iam studying')
  print('iam going to college')
  print('iam reading')
alekhya()
# Out:
# iam studying
# iam going to college
# iam reading

# %%
def sum(a,b):
  print(a+b)
sum(1,22)
# Out:
# 23

# %%
def num(x,y):
  if x % y == 0:
    print(x,'is not disivible by',y)
  else:
    print(y,'not divisible by' ,y)
num(4,5)
# Out:
# 5 not divisible by 5

# %%
def display(name,age):
  print('my name is',name,'and my age is',age)
display('alekhya',20)

# %%
r = 21
def alekhya():
  print(f"iam alekhya my age is :{r}")
alekhya()
print(f"iam anu my age is :{r}")
# Out:
# iam alekhya my age is :21
# iam anu my age is :21

# %%
def alekhya():
  global b
  b = 21
  print(f"iam alekhya iam {b}")
alekhya()
print(f"iam {b}")
# Out:
# iam alekhya iam 21
# iam 21

# %%
def table(n):
  for i in range(1,11):
    print(f'{n} x {i} = {n*i}')
table(6)
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
def even(a):
  for i in a:
    if i % 2== 0:
      print(f'even{i}')

a = [10,11,24,26]
even(a)
# Out:
# even10
# even24
# even26

# %%
def lst(*alekhya):
  print(type(alekhya))
  print(alekhya[1])
lst(1,2,3,4)
# Out:
# <class 'tuple'>
# 2

# %%
def alekhya(*allu):
  for i in allu:
    if i % 2 == 0:
      print(f'even {i}')
alekhya(10,20,30)
# Out:
# even 10
# even 20
# even 30

# %%
def allu(**n):
  print(n)

allu(apple = 300,caroot = 200)
# Out:
# {'apple': 300, 'caroot': 200}

# %%
def alekhya(a,b):
  for i in range(a,b):
    if i % 2 == 0:
      return f"even : {i}"
b = alekhya(10,20)
print(b)
# Out:
# even : 10

# %%
def alekhya(a,b):
  c = []
  for i in  range(a,b):
    if i % 2 == 0:
      c.append(i)
  return c

sol = alekhya(10,12)
print(sol)
# Out:
# [10]
