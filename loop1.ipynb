# %%
f = 457
s= 0
while f > 0:
  res = f % 10
  s = s + res
  f = f//10
print(s)
# Out:
# 16

# %%
f = 457
s = 0
while f>0:
  res = f%10
  s = s+res
  f = f//10
print(s)
# Out:
# 16

# %%
import math
math.factorial(5)
# Out:
# 120

# %%
n = 6
s = 1
for i in range(1,n+1):
  s = s*i
print(s)
# Out:
# 720

# %%
n = 4
s = 2
for i in range(1,1+n):
  s = s*i
print(s)
# Out:
# 48

# %%
n = 8
s = 0
for i in range(1,n):
  if n%i==0:
    s = s+i
  if n == s:
    print("perfect")
  else:
    print("noo")
# Out:
# noo
# noo
# noo
# noo
# noo
# noo
# noo

# %%
n = 10
s = 0
for i in range(1,n+1):
  if n % i == 0:
   s = s+1
if s == 2:
  print("prime")
else:
  print("no")
# Out:
# no

# %%
n = 121
t = n
s = 0
while n>0:
  res = n % 10
  s = (s*10) + res
  n = n//10
if n == s:
  print('palidrome')
else:
  print("no palidrome")
# Out:
# no palidrome

# %%
n = 121
t = n
s = 0
while n>0:
  res = n % 10
  s = s+ (res*res*res)
  n = n//10
if n == s:
  print('amstrong')
else:
  print("no amstrong")
# Out:
# no amstrong
